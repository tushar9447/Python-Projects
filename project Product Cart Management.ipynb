# %%
total_bill={}
product_dict={"p1":100,"p2":200,"p3":300,"p4":400}
product_cart={}

while True:
    for i in product_dict:
        print(i,"----->",product_dict[i])
        
    choice= int(input("press 1: To buy Product \npress 2: To remove From Cart \npress 3: Clear Cart \npress 4: Generate Bill \npress 5: Exit\n"))


    if (choice == 1):
        p_name = input("Enter Product Name to Buy : ")
        if p_name in product_dict:
            p_qty=int(input("Enter Product Quantity :"))   
            product_cart[p_name] = p_qty
        else:
            print("We Dont Have Such Product")

    elif (choice == 2):
        p_name = input("Enter product want to remove : ")
        if p_name in product_cart:
            p_qty = int(input("Enter Quantity : "))
            if (product_cart[p_name] > p_qty):
                    product_cart[p_name] -= p_qty
            else:
                print("Yow are Removining More Quantity")
                print(f"Your Cart : {Product_cart}")
        else:
            print("Product Not in Cart ")

    elif (choice == 3):
        product_cart= {}
        total_bill= {}

    elif (choice == 4):
        for i in product_cart:
            total_bill[i] = (product_cart[i]*product_dict[i])
        print("++++++++++++++++++++++++++++++++++++++")  
        print(f"Your cart : {product_cart}")
        print(f"Your Total Bill : {sum(total_bill.values())}")


    elif (choice == 5):
        break
# Out:
# p1 -----> 100
# p2 -----> 200
# p3 -----> 300
# p4 -----> 400
# press 1: To buy Product
# press 2: To remove From Cart
# press 3: Clear Cart
# press 4: Generate Bill
# press 5: Exit
# 1
# Enter Product Name to Buy : p1
# Enter Product Quantity :4
# p1 -----> 100
# p2 -----> 200
# p3 -----> 300
# p4 -----> 400
# press 1: To buy Product
# press 2: To remove From Cart
# press 3: Clear Cart
# press 4: Generate Bill
# press 5: Exit
# 4
# ++++++++++++++++++++++++++++++++++++++
# Your cart : {'p1': 4}
# Total Bill : 400
# p1 -----> 100
# p2 -----> 200
# p3 -----> 300
# p4 -----> 400
# press 1: To buy Product
# press 2: To remove From Cart
# press 3: Clear Cart
# press 4: Generate Bill
# press 5: Exit
# 1
# Enter Product Name to Buy : p1
# Enter Product Quantity :2
# p1 -----> 100
# p2 -----> 200
# p3 -----> 300
# p4 -----> 400
# press 1: To buy Product
# press 2: To remove From Cart
# press 3: Clear Cart
# press 4: Generate Bill
# press 5: Exit
# 4
# ++++++++++++++++++++++++++++++++++++++
# ...
